# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step 1 - Load data and price dataframe

# %%
xlu = pd.read_csv('~/Desktop/Quant Trading Project/data/xlu.csv', parse_dates=['Date'], date_format='%m/%d/%y', index_col='Date')   # change if needed
xlp = pd.read_csv('~/Desktop/Quant Trading Project/data/xlp.csv', parse_dates=['Date'], date_format='%m/%d/%y', index_col='Date')   # change if needed

xlu.columns = xlu.columns.str.strip()
xlp.columns = xlp.columns.str.strip()

xlu = pd.DataFrame({'Adj_Close': xlu['Close']})
xlp = pd.DataFrame({'Adj_Close': xlp['Close']})

xlu.sort_index(inplace=True)
xlp.sort_index(inplace=True)

# %%
prices = pd.DataFrame({
    "xlu": xlu["Adj_Close"],
    "xlp": xlp["Adj_Close"]
}).dropna()

# %%
prices["ratio"] = prices["xlu"] / prices["xlp"]

lookback = 60
prices["ratio_mean"] = prices["ratio"].rolling(lookback).mean()
prices["ratio_std"] = prices["ratio"].rolling(lookback).std()

prices["zscore"] = (prices["ratio"] - prices["ratio_mean"]) / prices["ratio_std"]

# %%
#Raw signal

entry_threshold = 2
exit_threshold = 0.5

prices["signal_raw"] = 0
prices.loc[prices["zscore"] < -entry_threshold, "signal_raw"] = 1
prices.loc[prices["zscore"] > entry_threshold, "signal_raw"] = -1

prices["signal_raw"].value_counts(dropna=False)
# Out:
# signal_raw
#  0    6047
# -1     460
#  1     370
# Name: count, dtype: int64

# %%
prices["position"] = 0

for i in range(1, len(prices)):
    prev_pos = prices["position"].iloc[i-1]
    z = prices["zscore"].iloc[i]
    raw = prices["signal_raw"].iloc[i]
    
    if prev_pos == 0:
        prices.iloc[i, prices.columns.get_loc("position")] = raw
    else:
        if abs(z) <= exit_threshold:
            prices.iloc[i, prices.columns.get_loc("position")] = 0
        else:
            prices.iloc[i, prices.columns.get_loc("position")] = prev_pos

# %%
#To avoid look ahead bias

prices["position_shifted"] = prices["position"].shift(1)

# %%
# Returns

prices["ret_xlu"] = prices["xlu"].pct_change()
prices["ret_xlp"] = prices["xlp"].pct_change()
prices = prices.dropna()

# %%
# Gross strategy returns

prices.loc[:,"spread_return_gross"] = prices["position_shifted"] * (prices["ret_xlu"] - prices["ret_xlp"])

# %%
transaction_cost = 0.001

prices["trade"] = prices["position"].diff().abs().fillna(0)
prices["cost"] = prices["trade"] * transaction_cost

prices["spread_return_net"] = prices["spread_return_gross"] - prices["cost"]

# %%
#Equity curves

prices["equity_gross"] = (1 + prices["spread_return_gross"]).cumprod()
prices["equity_net"] = (1 + prices["spread_return_net"]).cumprod()

# %%
#Flat baseline

prices["flat_return"] = 0.0
prices["flat_equity"] = (1 + prices["flat_return"]).cumprod()

# %% [markdown]
# ## Step 1 - Decide the parameters to test
#
# ## Sensitivity test setup
#
# Choosing a small grid of values to test:
# - Entry thresholds: 1.5, 2.0 and 2.5
# - Exit thresholds: 0.0, 0.5 and 1.0
# - Lookback windows: 30, 60 and 90
#
# For our previous signal we used a 60 day lookback and +2/-2 entry threshold - this will now be out baseline.
#
# Testing to see whether nearby values produce similar results or not.

# %% [markdown]
# ## Step 2 - Rebuilding the strategy inside a function
#
# To test parameters properly, we need a reusuable function

# %%
def backtest_pair_strategy(prices, lookback=60, entry_threshold=2.0, exit_threshold=0.5, transaction_cost=0.001):
    temp = prices.copy()
    
    temp["ratio"] = temp["xlu"] / temp["xlp"]
    temp["ratio_mean"] = temp["ratio"].rolling(lookback).mean()
    temp["ratio_std"] = temp["ratio"].rolling(lookback).std()
    temp["zscore"] = (temp["ratio"] - temp["ratio_mean"]) / temp["ratio_std"]
    
    temp["signal_raw"] = 0
    temp.loc[temp["zscore"] < -entry_threshold, "signal_raw"] = 1
    temp.loc[temp["zscore"] > entry_threshold, "signal_raw"] = -1
    
    temp["position"] = 0
    for i in range(1, len(temp)):
        prev_pos = temp["position"].iloc[i-1]
        z = temp["zscore"].iloc[i]
        raw = temp["signal_raw"].iloc[i]
        if prev_pos == 0:
            temp.iloc[i, temp.columns.get_loc("position")] = raw
        else:
            if abs(z) <= exit_threshold:
                temp.iloc[i, temp.columns.get_loc("position")] = 0
            else:
                temp.iloc[i, temp.columns.get_loc("position")] = prev_pos
    
    temp["position_shifted"] = temp["position"].shift(1)
    temp["ret_xlu"] = temp["xlu"].pct_change()
    temp["ret_xlp"] = temp["xlp"].pct_change()
    temp["trade"] = temp["position"].diff().abs().fillna(0)
    temp["spread_return_gross"] = temp["position_shifted"] * (temp["ret_xlu"] - temp["ret_xlp"])
    temp["spread_return_net"] = temp["spread_return_gross"] - temp["trade"] * transaction_cost
    temp = temp.dropna()
    
    equity = (1 + temp["spread_return_net"]).cumprod()
    
    annual_return = (1 + temp["spread_return_net"].mean())**252 - 1
    annual_vol = temp["spread_return_net"].std() * np.sqrt(252)
    sharpe = np.nan if annual_vol == 0 else annual_return / annual_vol
    max_dd = (equity / equity.cummax() - 1).min()
    
    return {
        "lookback": lookback,
        "entry_threshold": entry_threshold,
        "exit_threshold": exit_threshold,
        "annual_return": annual_return,
        "annual_vol": annual_vol,
        "sharpe": sharpe,
        "max_drawdown": max_dd,
        "trade_count": int((temp["trade"] > 0).sum())
    }

# %% [markdown]
# WHY THIS MATTERS:
# - This makes our strategy testable across different parameters/ settings instead of locking us in one setting.

# %% [markdown]
# ## Step 3 - Run the parameter grid

# %%
#Grid search

results = []

for lookback in [30, 60, 90]:
    for entry in [1.5, 2.0, 2.5]:
        for exit_th in [0.0, 0.5, 1.0]:
            if exit_th < entry:
                res = backtest_pair_strategy(prices, lookback=lookback, entry_threshold=entry, exit_threshold=exit_th)
                results.append(res)

results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 0        30              1.5             0.0      -0.005445    0.158390
# 1        30              1.5             0.5       0.019979    0.115745
# 2        30              1.5             1.0       0.018060    0.103162
# 3        30              2.0             0.0      -0.003890    0.158117
# 4        30              2.0             0.5       0.022670    0.102405
#
#      sharpe  max_drawdown  trade_count
# 0 -0.034379     -0.565378            1
# 1  0.172612     -0.377635          590
# 2  0.175066     -0.376956          784
# 3 -0.024600     -0.565378            1
# 4  0.221380     -0.334648          404

# %%
results_df.head(27)
# Out:
#     lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 0         30              1.5             0.0      -0.005445    0.158390
# 1         30              1.5             0.5       0.019979    0.115745
# 2         30              1.5             1.0       0.018060    0.103162
# 3         30              2.0             0.0      -0.003890    0.158117
# 4         30              2.0             0.5       0.022670    0.102405
# 5         30              2.0             1.0       0.025388    0.089454
# 6         30              2.5             0.0      -0.002604    0.157797
# 7         30              2.5             0.5       0.022492    0.075943
# 8         30              2.5             1.0       0.015276    0.066670
# 9         60              1.5             0.0      -0.002616    0.158147
# 10        60              1.5             0.5       0.061587    0.117501
# 11        60              1.5             1.0       0.047256    0.102787
# 12        60              2.0             0.0      -0.001808    0.157874
# 13        60              2.0             0.5       0.060886    0.104287
# 14        60              2.0             1.0       0.057848    0.088923
# 15        60              2.5             0.0      -0.000515    0.156994
# 16        60              2.5             0.5       0.052046    0.087356
# 17        60              2.5             1.0       0.046196    0.070874
# 18        90              1.5             0.0      -0.001816    0.158226
# 19        90              1.5             0.5       0.077656    0.119612
# 20        90              1.5             1.0       0.053204    0.104625
# 21        90              2.0             0.0      -0.000518    0.157344
# 22        90              2.0             0.5       0.063119    0.107790
# 23        90              2.0             1.0       0.046795    0.093405
# 24        90              2.5             0.0      -0.000518    0.157344
# 25        90              2.5             0.5       0.072695    0.091249
# 26        90              2.5             1.0       0.055125    0.078666
#
#       sharpe  max_drawdown  trade_count
# 0  -0.034379     -0.565378            1
# 1   0.172612     -0.377635          590
# 2   0.175066     -0.376956          784
# 3  -0.024600     -0.565378            1
# 4   0.221380     -0.334648          404
# 5   0.283814     -0.384759          476
# 6  -0.016503     -0.565378            1
# 7   0.296165     -0.256041          204
# 8   0.229124     -0.279417          218
# 9  -0.016539     -0.565378            1
# 10  0.524142     -0.283502          374
# 11  0.459744     -0.196232          508
# 12 -0.011452     -0.565378            1
# 13  0.583838     -0.223067          260
# 14  0.650534     -0.148087          304
# 15 -0.003282     -0.565378            1
# 16  0.595792     -0.194751          158
# 17  0.651799     -0.106186          166
# 18 -0.011477     -0.565378            1
# 19  0.649237     -0.271529          300
# 20  0.508515     -0.248772          404
# 21 -0.003289     -0.565378            1
# 22  0.585577     -0.245666          192
# 23  0.500993     -0.282435          224
# 24 -0.003289     -0.565378            1
# 25  0.796663     -0.190697          132
# 26  0.700749     -0.190697          142

# %%
#This line of code is the same as the above, however adds a timer to see how long it is taking for the code to finish

from tqdm import tqdm
import itertools

results = []
combos = [(l, e, x) for l in [30, 60, 90] for e in [1.5, 2.0, 2.5] for x in [0.0, 0.5, 1.0] if x < e]

for lookback, entry, exit_th in tqdm(combos):
    res = backtest_pair_strategy(prices, lookback=lookback, entry_threshold=entry, exit_threshold=exit_th)
    results.append(res)

results_df = pd.DataFrame(results)
results_df.head()
# Out:
# 100%|███████████████████████████████████████████| 27/27 [00:52<00:00,  1.96s/it]
#    lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 0        30              1.5             0.0      -0.005445    0.158390
# 1        30              1.5             0.5       0.019979    0.115745
# 2        30              1.5             1.0       0.018060    0.103162
# 3        30              2.0             0.0      -0.003890    0.158117
# 4        30              2.0             0.5       0.022670    0.102405
#
#      sharpe  max_drawdown  trade_count
# 0 -0.034379     -0.565378            1
# 1  0.172612     -0.377635          590
# 2  0.175066     -0.376956          784
# 3 -0.024600     -0.565378            1
# 4  0.221380     -0.334648          404

# %%
print((results_df["annual_return"] > 0).sum())
print((results_df["annual_return"] <= 0).sum())
# Out:
# 18
# 9

# %% [markdown]
# WHAT TO LOOK FOR:
#
# Are many combinations profitable?
# - 18/27 combinations are profitable.
# - That is 66% of all combinations are profitable.
#
# Or only one small cluster?
# - Clearly there is no small cluster.
#
# Does performance collapse outside the baseline?
# - No it does not.
#
# - Intriguing information from the test is that when the exit thresholf is set a exactly 0, we always get a negative return - aka a loss.

# %% [markdown]
# ## Step 4 - Rank the best settings

# %%
#Sort by Sharpe

results_df.sort_values("sharpe", ascending=False).head(10)
# Out:
#     lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 25        90              2.5             0.5       0.072695    0.091249
# 26        90              2.5             1.0       0.055125    0.078666
# 17        60              2.5             1.0       0.046196    0.070874
# 14        60              2.0             1.0       0.057848    0.088923
# 19        90              1.5             0.5       0.077656    0.119612
# 16        60              2.5             0.5       0.052046    0.087356
# 22        90              2.0             0.5       0.063119    0.107790
# 13        60              2.0             0.5       0.060886    0.104287
# 10        60              1.5             0.5       0.061587    0.117501
# 20        90              1.5             1.0       0.053204    0.104625
#
#       sharpe  max_drawdown  trade_count
# 25  0.796663     -0.190697          132
# 26  0.700749     -0.190697          142
# 17  0.651799     -0.106186          166
# 14  0.650534     -0.148087          304
# 19  0.649237     -0.271529          300
# 16  0.595792     -0.194751          158
# 22  0.585577     -0.245666          192
# 13  0.583838     -0.223067          260
# 10  0.524142     -0.283502          374
# 20  0.508515     -0.248772          404

# %%
#Sort by return

results_df.sort_values("annual_return", ascending=False).head(10)
# Out:
#     lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 19        90              1.5             0.5       0.077656    0.119612
# 25        90              2.5             0.5       0.072695    0.091249
# 22        90              2.0             0.5       0.063119    0.107790
# 10        60              1.5             0.5       0.061587    0.117501
# 13        60              2.0             0.5       0.060886    0.104287
# 14        60              2.0             1.0       0.057848    0.088923
# 26        90              2.5             1.0       0.055125    0.078666
# 20        90              1.5             1.0       0.053204    0.104625
# 16        60              2.5             0.5       0.052046    0.087356
# 11        60              1.5             1.0       0.047256    0.102787
#
#       sharpe  max_drawdown  trade_count
# 19  0.649237     -0.271529          300
# 25  0.796663     -0.190697          132
# 22  0.585577     -0.245666          192
# 10  0.524142     -0.283502          374
# 13  0.583838     -0.223067          260
# 14  0.650534     -0.148087          304
# 26  0.700749     -0.190697          142
# 20  0.508515     -0.248772          404
# 16  0.595792     -0.194751          158
# 11  0.459744     -0.196232          508

# %% [markdown]
# ## Step 5 - Build a heat map for Sharpe
#
# You can visualise how sensitive the strategy is

# %%
# Heat map pivot

pivot_sharpe = results_df.pivot_table(index="entry_threshold", columns="lookback", values="sharpe", aggfunc="mean")
pivot_sharpe
# Out:
# lookback               30        60        90
# entry_threshold
# 1.5              0.104433  0.322449  0.382092
# 2.0              0.160198  0.407640  0.361093
# 2.5              0.169595  0.414770  0.498041

# %%
#Plot heat map

plt.figure(figsize=(8,5))
plt.imshow(pivot_sharpe, aspect="auto", cmap="coolwarm", origin="lower")
plt.colorbar(label="Sharpe")
plt.xticks(range(len(pivot_sharpe.columns)), pivot_sharpe.columns)
plt.yticks(range(len(pivot_sharpe.index)), pivot_sharpe.index)
plt.xlabel("Lookback")
plt.ylabel("Entry Threshold")
plt.title("Sharpe Sensitivity Heat Map")
plt.show()

# %% [markdown]
# WHAT THIS TELLS ME:
#
# - A broad warm area is better than one tiny hot spot.
# - It is clear from the heat map above we have one tiny hot spot where 90 and 2.5 converge.

# %% [markdown]
# ## Step 6 - Build a heat map for cumulative return

# %%
pivot_return = results_df.pivot_table(index="entry_threshold", columns="lookback", values="annual_return", aggfunc="mean")
pivot_return
# Out:
# lookback               30        60        90
# entry_threshold
# 1.5              0.010865  0.035409  0.043015
# 2.0              0.014723  0.038975  0.036466
# 2.5              0.011721  0.032576  0.042434

# %%
plt.figure(figsize=(8,5))
plt.imshow(pivot_return, aspect="auto", cmap="viridis", origin="lower")
plt.colorbar(label="Annual Return")
plt.xticks(range(len(pivot_return.columns)), pivot_return.columns)
plt.yticks(range(len(pivot_return.index)), pivot_return.index)
plt.xlabel("Lookback")
plt.ylabel("Entry Threshold")
plt.title("Return Sensitivity Heat Map")
plt.show()

# %%
# Trade count table

# %% [markdown]
# ## Step 7 - Look at trade frequency

# %%
# Trade count

results_df.sort_values("trade_count", ascending=False).head(10)
# Out:
#     lookback  entry_threshold  exit_threshold  annual_return  annual_vol  \
# 2         30              1.5             1.0       0.018060    0.103162
# 1         30              1.5             0.5       0.019979    0.115745
# 11        60              1.5             1.0       0.047256    0.102787
# 5         30              2.0             1.0       0.025388    0.089454
# 4         30              2.0             0.5       0.022670    0.102405
# 20        90              1.5             1.0       0.053204    0.104625
# 10        60              1.5             0.5       0.061587    0.117501
# 14        60              2.0             1.0       0.057848    0.088923
# 19        90              1.5             0.5       0.077656    0.119612
# 13        60              2.0             0.5       0.060886    0.104287
#
#       sharpe  max_drawdown  trade_count
# 2   0.175066     -0.376956          784
# 1   0.172612     -0.377635          590
# 11  0.459744     -0.196232          508
# 5   0.283814     -0.384759          476
# 4   0.221380     -0.334648          404
# 20  0.508515     -0.248772          404
# 10  0.524142     -0.283502          374
# 14  0.650534     -0.148087          304
# 19  0.649237     -0.271529          300
# 13  0.583838     -0.223067          260

# %% [markdown]
# WHY THIS MATTERS:
#
# - Sometimes a strategy can look better due high number of trades, however that can make it more expensive and less realisitic.

# %% [markdown]
# # Robustness judgement
#
# Does performance persist across many parameter settings?
# - No it does NOT, we see at some parameters it does. However, it does NOT hold for many parameter settings - showing a weakness in the strategy.
#
# Is there one narrow “best” region?
# - Yes - shown clear in the heat map.
#
# Does the strategy survive transaction costs?
# - No, plots from previous coding sessino show this.
#
# Would I trust this live?
# - No, needs to be worked on.
#
# Is this a strong idea or just a learning example?
# - Learning example
#
#
# ## Judgement
#
# - The strategy has a narrow pocket of decent performance, but robustness is weak.
# -  Results vary drastically with the choice of the lookback and threshold.
# - Transcations costs reduce the edge significantly.
# - I would not trust live yet.
